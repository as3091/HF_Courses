# %% [markdown]
# <a href="https://colab.research.google.com/github/as3091/HF_Courses/blob/main/notebooks/unit3/unit3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /private/var/folders/t_/4s6ks7w51kl198_qmtkxn31m0000gp/T/pip-req-build-bf2tktsi
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /private/var/folders/t_/4s6ks7w51kl198_qmtkxn31m0000gp/T/pip-req-build-bf2tktsi
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit f94cef4e59fb2f03b77177db432c3f771d0ee72c
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3_contrib<3.0,>=2.9.0 (from rl_zoo3==2.9.2a0)
#   Downloading sb3_contrib-2.9.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting gymnasium<2.0,>=0.29.1 (from rl_zoo3==2.9.2a0)
#   Downloading gymnasium-1.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting huggingface_sb3<4.0,>=3.0 (from rl_zoo3==2.9.2a0)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from rl_zoo3==2.9.2a0) (4.67.3)
# Requirement already satisfied: rich in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from rl_zoo3==2.9.2a0) (15.0.0)
# Collecting optuna>=3.0 (from rl_zoo3==2.9.2a0)
#   Downloading optuna-4.9.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pyyaml>=5.1 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from rl_zoo3==2.9.2a0) (6.0.3)
# Collecting pytablewriter~=1.2 (from rl_zoo3==2.9.2a0)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting shimmy~=2.0 (from rl_zoo3==2.9.2a0)
#   Downloading shimmy-2.0.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy>=1.21.0 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from gymnasium<2.0,>=0.29.1->rl_zoo3==2.9.2a0) (2.4.2)
# Collecting cloudpickle>=1.2.0 (from gymnasium<2.0,>=0.29.1->rl_zoo3==2.9.2a0)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from gymnasium<2.0,>=0.29.1->rl_zoo3==2.9.2a0) (4.15.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<2.0,>=0.29.1->rl_zoo3==2.9.2a0)
#   Downloading farama_notifications-0.0.6-py3-none-any.whl.metadata (729 bytes)
# Collecting huggingface-hub~=0.8 (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.2a0)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Collecting wasabi (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.2a0)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: filelock in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.2a0) (3.28.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.2a0) (2026.3.0)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.2a0)
#   Downloading hf_xet-1.6.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: packaging>=20.9 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.2a0) (26.0)
# Requirement already satisfied: requests in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.2a0) (2.32.5)
# Requirement already satisfied: setuptools>=38.3.0 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from pytablewriter~=1.2->rl_zoo3==2.9.2a0) (81.0.0)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter~=1.2->rl_zoo3==2.9.2a0)
#   Downloading dataproperty-1.1.1-py3-none-any.whl.metadata (12 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=1.2->rl_zoo3==2.9.2a0)
#   Downloading mbstrdecoder-1.1.5-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter~=1.2->rl_zoo3==2.9.2a0)
#   Downloading pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter~=1.2->rl_zoo3==2.9.2a0)
#   Downloading tabledata-1.3.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=1.2->rl_zoo3==2.9.2a0)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.9.2a0)
#   Downloading typepy-1.3.5-py3-none-any.whl.metadata (9.6 kB)
# Collecting chardet<7,>=3.0.4 (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3==2.9.2a0)
#   Downloading chardet-6.0.0.post1-py3-none-any.whl.metadata (3.3 kB)
# Collecting stable_baselines3<3.0,>=2.9.0 (from sb3_contrib<3.0,>=2.9.0->rl_zoo3==2.9.2a0)
#   Downloading stable_baselines3-2.9.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: torch<3.0,>=2.8 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from stable_baselines3<3.0,>=2.9.0->sb3_contrib<3.0,>=2.9.0->rl_zoo3==2.9.2a0) (2.11.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from torch<3.0,>=2.8->stable_baselines3<3.0,>=2.9.0->sb3_contrib<3.0,>=2.9.0->rl_zoo3==2.9.2a0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from torch<3.0,>=2.8->stable_baselines3<3.0,>=2.9.0->sb3_contrib<3.0,>=2.9.0->rl_zoo3==2.9.2a0) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from torch<3.0,>=2.8->stable_baselines3<3.0,>=2.9.0->sb3_contrib<3.0,>=2.9.0->rl_zoo3==2.9.2a0) (3.1.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.9.2a0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.9 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.9.2a0) (2026.2)
# Requirement already satisfied: six>=1.5 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.9.2a0) (1.17.0)
# Collecting alembic>=1.5.0 (from optuna>=3.0->rl_zoo3==2.9.2a0)
#   Downloading alembic-1.19.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna>=3.0->rl_zoo3==2.9.2a0)
#   Downloading colorlog-6.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from optuna>=3.0->rl_zoo3==2.9.2a0) (1.4.54)
# Collecting Mako (from alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.9.2a0)
#   Downloading mako-1.4.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from sympy>=1.13.3->torch<3.0,>=2.8->stable_baselines3<3.0,>=2.9.0->sb3_contrib<3.0,>=2.9.0->rl_zoo3==2.9.2a0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from jinja2->torch<3.0,>=2.8->stable_baselines3<3.0,>=2.9.0->sb3_contrib<3.0,>=2.9.0->rl_zoo3==2.9.2a0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.2a0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.2a0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.2a0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.9.2a0) (2026.1.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from rich->rl_zoo3==2.9.2a0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from rich->rl_zoo3==2.9.2a0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.9.2a0) (0.1.2)
# Downloading gymnasium-1.3.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 22.2 MB/s  0:00:00
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 22.7 MB/s  0:00:00
# Downloading hf_xet-1.6.0-cp38-abi3-macosx_11_0_arm64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 26.2 MB/s  0:00:00
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
# Downloading dataproperty-1.1.1-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.5-py3-none-any.whl (8.0 kB)
# Downloading chardet-6.0.0.post1-py3-none-any.whl (627 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 627.2/627.2 kB 22.0 MB/s  0:00:00
# Downloading pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Downloading sb3_contrib-2.9.0-py3-none-any.whl (93 kB)
# Downloading shimmy-2.0.1-py3-none-any.whl (30 kB)
# Downloading stable_baselines3-2.9.0-py3-none-any.whl (187 kB)
# Downloading tabledata-1.3.5-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.5-py3-none-any.whl (31 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading farama_notifications-0.0.6-py3-none-any.whl (2.9 kB)
# Downloading optuna-4.9.0-py3-none-any.whl (425 kB)
# Downloading alembic-1.19.1-py3-none-any.whl (265 kB)
# Downloading colorlog-6.12.0-py3-none-any.whl (12 kB)
# Downloading mako-1.4.1-py3-none-any.whl (80 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Building wheels for collected packages: rl_zoo3
#   Building wheel for rl_zoo3 (pyproject.toml) ... done
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.9.2a0-py3-none-any.whl size=79022 sha256=ee20d61c9ac4a78a5874119c9f9cf720412a2b987f20ef86e74262676ae505db
#   Stored in directory: /private/var/folders/t_/4s6ks7w51kl198_qmtkxn31m0000gp/T/pip-ephem-wheel-cache-c0jwjjtb/wheels/cd/09/5b/8130538724a187021e02afe53ce7a1269c516a78a487a1ba15
# Successfully built rl_zoo3
# Installing collected packages: farama-notifications, wasabi, tcolorpy, pathvalidate, Mako, hf-xet, colorlog, cloudpickle, chardet, mbstrdecoder, huggingface-hub, gymnasium, alembic, typepy, stable_baselines3, shimmy, optuna, huggingface_sb3, sb3_contrib, DataProperty, tabledata, pytablewriter, rl_zoo3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/23 [rl_zoo3]1/23 [pytablewriter]es3]
# Successfully installed DataProperty-1.1.1 Mako-1.4.1 alembic-1.19.1 chardet-6.0.0.post1 cloudpickle-3.1.2 colorlog-6.12.0 farama-notifications-0.0.6 gymnasium-1.3.0 hf-xet-1.6.0 huggingface-hub-0.36.2 huggingface_sb3-3.0 mbstrdecoder-1.1.5 optuna-4.9.0 pathvalidate-3.3.1 pytablewriter-1.2.1 rl_zoo3-2.9.2a0 sb3_contrib-2.9.0 shimmy-2.0.1 stable_baselines3-2.9.0 tabledata-1.3.5 tcolorpy-0.1.7 typepy-1.3.5 wasabi-1.1.3

# %%
# !apt-get install swig cmake ffmpeg
# !yes | brew install swig cmake ffmpeg
# Out:
# Warning: swig 4.5.0 is already installed and up-to-date.
# To reinstall 4.5.0, run:
#   brew reinstall swig
# Warning: cmake 4.4.2 is already installed and up-to-date.
# To reinstall 4.4.2, run:
#   brew reinstall cmake
# Warning: ffmpeg 9.0.1 is already installed and up-to-date.
# To reinstall 9.0.1, run:
#   brew reinstall ffmpeg
# yes: stdout: Broken pipe

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install "gymnasium[atari]"
# !pip install "gymnasium[accept-rom-license]"
# Out:
# Requirement already satisfied: gymnasium[atari] in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from gymnasium[atari]) (2.4.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from gymnasium[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from gymnasium[atari]) (0.0.6)
# Collecting ale_py>=0.9 (from gymnasium[atari])
#   Downloading ale_py-0.12.1-cp312-cp312-macosx_13_0_arm64.whl.metadata (9.7 kB)
# Downloading ale_py-0.12.1-cp312-cp312-macosx_13_0_arm64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 2.2 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: ale_py
# Successfully installed ale_py-0.12.1
# Requirement already satisfied: gymnasium[accept-rom-license] in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (1.3.0)
# WARNING: gymnasium 1.3.0 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from gymnasium[accept-rom-license]) (2.4.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from gymnasium[accept-rom-license]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from gymnasium[accept-rom-license]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages (from gymnasium[accept-rom-license]) (0.0.6)

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# # Virtual display
# from pyvirtualdisplay import Display

# virtual_display = Display(visible=0, size=(1400, 900))
# virtual_display.start()

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# !python -m rl_zoo3.train --algo dqn --env SpaceInvadersNoFrameskip-v4  -f logs/  -c dqn.yml
# Out:
# /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (6.0.0.post1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 575491373
# Loading hyperparameters from: dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 1000000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.12.1+8a8fafb)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cpu device
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.55e+03 |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1603     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 592      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.69e+03 |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1770     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1616     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.43e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1751     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.75e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1820     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3791     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1830     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4391     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.52e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1833     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4947     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.45e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1833     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5565     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1834     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6054     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.41e+03 |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1846     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 7110     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.4e+03  |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1849     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7808     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.34e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1849     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 8329     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.41e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1855     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 9476     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1858     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 10283    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.4e+03  |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1859     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 10865    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.34e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1859     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 11452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.28e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1860     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 11935    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.25e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1861     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 12531    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1861     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 13097    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1861     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 13800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1862     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 14364    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1864     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 15326    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1864     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 15893    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1863     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 16430    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1862     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 16884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1857     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 17939    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1851     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 18516    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1851     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 18908    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1852     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 19536    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1852     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 20075    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1853     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 20642    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.79     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1852     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 21208    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1853     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 21789    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.778    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1854     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 22409    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1854     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 23029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.764    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1856     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 23847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.758    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1856     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 24449    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=171.00 +/- 37.47
# Episode length: 2353.80 +/- 236.43
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.35e+03 |
# |    mean_reward      | 171      |
# | rollout/            |          |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1635     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 25361    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.744    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1638     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 25878    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1642     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 26408    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.732    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1648     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 27102    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.719    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1658     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 28376    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1661     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 28839    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1664     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 29361    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.703    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1668     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 30018    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.698    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1667     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 30531    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.691    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1671     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 31162    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.686    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1675     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 31745    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.68     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1677     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 32307    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.67     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1684     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 33375    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.664    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1687     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 33895    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.653    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1693     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 35067    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.647    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1696     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 35700    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.637    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1701     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 36677    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1701     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 37510    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.622    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1703     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 38169    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.614    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1707     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 38968    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.609    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1709     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 39482    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.604    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1711     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 40043    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.598    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1712     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 40624    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1715     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 41292    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.585    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1717     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 41927    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.579    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1719     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 42564    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.573    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1721     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 43156    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.566    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1724     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 43837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.561    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1722     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 44363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.554    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1724     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 45017    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.548    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1726     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 45624    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.537    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1730     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 46730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.532    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1732     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 47245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.523    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1734     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 48164    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1734     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 48598    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.512    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1736     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 49269    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=171.00 +/- 18.00
# Episode length: 2482.20 +/- 66.48
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.48e+03 |
# |    mean_reward      | 171      |
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.499    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1624     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 50606    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.494    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1626     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 51085    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.487    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1629     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 51821    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.484    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1630     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 52165    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.478    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1632     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 52684    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.469    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1636     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 53678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.463    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1638     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 54235    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.458    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1640     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 54784    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.452    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1642     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 55305    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1645     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 56106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.435    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1647     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 57106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.429    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1648     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 57704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.422    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1650     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 58410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.418    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1651     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 58775    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.412    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1651     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 59430    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.406    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1652     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 59953    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1654     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 60644    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.388    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1658     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 61787    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.383    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1660     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 62360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.376    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1662     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 62987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.372    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1663     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 63400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.367    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1664     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 63921    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.362    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1666     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 64434    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.356    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1667     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 65058    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.347    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1670     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 65944    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.34     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 1672     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 66621    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.333    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 1674     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 67391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.326    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1676     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 68046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.321    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1677     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 68590    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.313    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1680     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 69379    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.309    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1681     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 69847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.299    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1684     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 70834    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.292    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1685     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 71481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.283    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 1686     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 72399    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.277    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 1688     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 73075    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 1690     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 73742    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.266    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 1690     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 74170    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.26     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1692     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 74737    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=138.00 +/- 16.61
# Episode length: 2343.40 +/- 190.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.34e+03 |
# |    mean_reward      | 138      |
# | rollout/            |          |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.255    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 1614     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 75280    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.249    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 1616     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 75882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.24     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 1619     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 76764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.233    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 1620     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 77459    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.226    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1622     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 78160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.218    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 1624     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 78953    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.212    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 1626     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 79590    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.199    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 1630     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 80889    |
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0284   |
# |    n_updates        | 213660   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 610      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3648     |
# |    fps              | 74       |
# |    time_elapsed     | 12805    |
# |    total_timesteps  | 955954   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0214   |
# |    n_updates        | 213988   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | 610      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3652     |
# |    fps              | 74       |
# |    time_elapsed     | 12825    |
# |    total_timesteps  | 957683   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00869  |
# |    n_updates        | 214420   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | 613      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3656     |
# |    fps              | 74       |
# |    time_elapsed     | 12846    |
# |    total_timesteps  | 959597   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 214899   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | 607      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3660     |
# |    fps              | 74       |
# |    time_elapsed     | 12857    |
# |    total_timesteps  | 960540   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 215134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 598      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3664     |
# |    fps              | 74       |
# |    time_elapsed     | 12874    |
# |    total_timesteps  | 962066   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 215516   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 598      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3668     |
# |    fps              | 74       |
# |    time_elapsed     | 12893    |
# |    total_timesteps  | 963507   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00975  |
# |    n_updates        | 215876   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3672     |
# |    fps              | 74       |
# |    time_elapsed     | 12918    |
# |    total_timesteps  | 965143   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 216285   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 598      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3676     |
# |    fps              | 74       |
# |    time_elapsed     | 12934    |
# |    total_timesteps  | 966261   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 216565   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3680     |
# |    fps              | 74       |
# |    time_elapsed     | 12956    |
# |    total_timesteps  | 967899   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 216974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3684     |
# |    fps              | 74       |
# |    time_elapsed     | 12976    |
# |    total_timesteps  | 969036   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 217258   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3688     |
# |    fps              | 74       |
# |    time_elapsed     | 12997    |
# |    total_timesteps  | 970529   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 217632   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 597      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3692     |
# |    fps              | 74       |
# |    time_elapsed     | 13020    |
# |    total_timesteps  | 972049   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0311   |
# |    n_updates        | 218012   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 598      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3696     |
# |    fps              | 74       |
# |    time_elapsed     | 13048    |
# |    total_timesteps  | 974049   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.157    |
# |    n_updates        | 218512   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=578.00 +/- 102.84
# Episode length: 3887.00 +/- 524.88
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.89e+03 |
# |    mean_reward      | 578      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0482   |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98e+03 |
# |    ep_rew_mean      | 601      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3700     |
# |    fps              | 74       |
# |    time_elapsed     | 13076    |
# |    total_timesteps  | 975728   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0626   |
# |    n_updates        | 218931   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | 603      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3704     |
# |    fps              | 74       |
# |    time_elapsed     | 13096    |
# |    total_timesteps  | 977327   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 219331   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99e+03 |
# |    ep_rew_mean      | 606      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3708     |
# |    fps              | 74       |
# |    time_elapsed     | 13110    |
# |    total_timesteps  | 978546   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 219636   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99e+03 |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3712     |
# |    fps              | 74       |
# |    time_elapsed     | 13136    |
# |    total_timesteps  | 980589   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0442   |
# |    n_updates        | 220147   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 606      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3716     |
# |    fps              | 74       |
# |    time_elapsed     | 13152    |
# |    total_timesteps  | 982121   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 220530   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 609      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3720     |
# |    fps              | 74       |
# |    time_elapsed     | 13171    |
# |    total_timesteps  | 983702   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0239   |
# |    n_updates        | 220925   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99e+03 |
# |    ep_rew_mean      | 607      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3724     |
# |    fps              | 74       |
# |    time_elapsed     | 13188    |
# |    total_timesteps  | 984998   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0082   |
# |    n_updates        | 221249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99e+03 |
# |    ep_rew_mean      | 608      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3728     |
# |    fps              | 74       |
# |    time_elapsed     | 13217    |
# |    total_timesteps  | 987126   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00767  |
# |    n_updates        | 221781   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99e+03 |
# |    ep_rew_mean      | 607      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3732     |
# |    fps              | 74       |
# |    time_elapsed     | 13229    |
# |    total_timesteps  | 988082   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0256   |
# |    n_updates        | 222020   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 597      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3736     |
# |    fps              | 74       |
# |    time_elapsed     | 13247    |
# |    total_timesteps  | 989539   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 222384   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 598      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3740     |
# |    fps              | 74       |
# |    time_elapsed     | 13270    |
# |    total_timesteps  | 991371   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00825  |
# |    n_updates        | 222842   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | 592      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3744     |
# |    fps              | 74       |
# |    time_elapsed     | 13303    |
# |    total_timesteps  | 994078   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00893  |
# |    n_updates        | 223519   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | 590      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3748     |
# |    fps              | 74       |
# |    time_elapsed     | 13320    |
# |    total_timesteps  | 995489   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0322   |
# |    n_updates        | 223872   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3752     |
# |    fps              | 74       |
# |    time_elapsed     | 13341    |
# |    total_timesteps  | 997274   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 224318   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | 585      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3756     |
# |    fps              | 74       |
# |    time_elapsed     | 13359    |
# |    total_timesteps  | 998802   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0193   |
# |    n_updates        | 224700   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=687.00 +/- 228.16
# Episode length: 4800.20 +/- 1481.25
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.8e+03  |
# |    mean_reward      | 687      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_1

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# /Users/as-mac-1143/miniforge3/lib/python3.12/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (6.0.0.post1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.12.1+8a8fafb)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 600.00
# Atari Episode Length 4315
# Atari Episode Score: 520.00
# Atari Episode Length 3849
# Atari Episode Score: 410.00
# Atari Episode Length 3229
# Atari Episode Score: 600.00
# Atari Episode Length 4217
# Atari Episode Score: 540.00
# Atari Episode Length 3967

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name _____________________ -orga _____________________ -f logs/

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga ThomasSimonini  -f logs/

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
